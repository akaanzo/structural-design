# %%
import pandas as pd
import numpy as np
# from sage.symbolic.substitution_map import make_map
import sympy as sp
from sympy import *
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly import graph_objects as go
import plotly.express as px
from IPython.display import Image
import seaborn as sns
sns.set(font='Franklin Gothic Book',
        rc={
 'axes.axisbelow': False,
 'axes.edgecolor': 'lightgrey',
 'axes.facecolor': 'None',
 'axes.grid': False,
 'grid.color':'#D5D5D5',
 'axes.labelcolor': 'dimgrey',
 'axes.spines.right': False,
 'axes.spines.top': False,
 'figure.facecolor': '#FEFCFB',
 'lines.solid_capstyle': 'round',
 'patch.edgecolor': 'w',
 'patch.force_edgecolor': True,
 'text.color': 'dimgrey',
 'xtick.bottom': False,
 'xtick.color': 'dimgrey',
 'xtick.direction': 'out',
 'xtick.top': False,
 'ytick.color': 'dimgrey',
 'ytick.direction': 'out',
 'ytick.left': False,
 'ytick.right': False})
sns.set_context("notebook", rc={"font.size":16,
                                "axes.titlesize":20,
                                "axes.labelsize":18})

# %%
epsilonc = np.arange(0, 2.01, .01)
fcd = 25+.85/1.5
sigmac = fcd*(1-(1-epsilonc/2)**2)

# %%
plt.figure(figsize=(16,8))
plt.plot(epsilonc, sigmac, color='#7FA5A5', linewidth='4')
plt.plot(np.arange(2, 3.51, .01), fcd*np.ones(len(np.arange(2, 3.51, .01))), color='#7FA5A5', linewidth='4')
plt.xlabel(r'$\epsilon_c$')
plt.ylabel(r'$\sigma_c$')
plt.xticks([0, 2, 3.5], [r'$0$',r'$\epsilon_{c2}$', r'$\epsilon_{cu}$' ], fontsize='16')
plt.yticks([fcd], [r'$f_{cd}$'], fontsize='16')
plt.xlim(0, 3.6)
plt.ylim(0, fcd+1)
plt.grid(True)
plt.title('Legame costitutivo del calcestruzzo\nParabola esponenzial rettangolo')
plt.savefig('export/img/legameCostitutivoCLS.pdf', bbox_inches='tight')

# %%
fyk = 450
fyd = round(fyk/1.15, 1)
Es = 210*10**3
epsilonse = round(fyd/Es,6)*1000
epsilons = np.linspace(0, epsilonse, 1000)
sigmas = np.linspace(0, fyd, 1000)

# %%
fyd
# Out:
# 391.3

# %%
plt.figure(figsize=(16,8))
plt.plot(epsilons, sigmas, color='#7FA5A5', linewidth='4')
plt.plot(np.arange(epsilonse,10, .01), fyd*np.ones(len(np.arange(epsilonse, 10, .01))), color='#7FA5A5', linewidth='4')
plt.xlabel(r'$\epsilon_s$')
plt.ylabel(r'$\sigma_s$')
plt.xticks([0, epsilonse, 10], [r'$0$',r'$\epsilon_{se}$', r'$\epsilon_{su}$' ], fontsize='16')
plt.yticks([fyd], [r'$f_{yd}$'], fontsize='16')
plt.xlim(0, 10.1)
plt.ylim(0, fyd+10)
plt.grid(True)
plt.title('Legame costitutivo acciaio\nElastico - perfettamente plastico')
plt.savefig('export/img/legameCostitutivoAcciaio.pdf', bbox_inches='tight')
